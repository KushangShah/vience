# %% [markdown]
# ## Introduction to Strings

# %% [markdown]
# * Strings are used in Python to record text information, such as names. It could either be a word, a phrase, a sentence, a paragraph or an entire encyclopedia. Strings in Python are actually a *sequence*, which     basically means Python keeps track of every element in the string as a sequence. For example, Python understands the string "joker' to be a sequence of letters in a specific order. This means we will be able to use indexing to grab particular letters (like the first letter, or the last letter).
#
#
# * This idea of a sequence is an important one in Python and we will touch upon it later on in the future.

# %%
first_string = 'hello world'
first_string
# Out:
# 'hello world'

# %%
second_string = "Learning Python"

# %%
third_string = '''I will be the best Data Scientist'''

# %%
third_string_2 = """I will be the best Data Scientist"""

# %%
fourth_string = "Hey, is this valid"

# %%
type(first_string)
# Out:
# str

# %% [markdown]
# ###  Creating a String
# * To create a string in Python you need to use either single quotes or double quotes. For example:

# %%
# Single word
my_first_string= 'algebra'
my_first_string
# Out:
# 'algebra'

# %%
# Entire phrase 
phrase = 'Statistics sits at the heart of machine learning'
print(phrase)
# Out:
# Statistics sits at the heart of machine learning

# %%
# Statement to get the type of the variable
type(phrase)
# Out:
# str

# %%
# We can also use double quote
my_string = "String built with double quotes"
print(my_string)   # Use the print command
# Out:
# String built with double quotes

# %%
var_temp_str = 'Hello World'

# %%
# Be careful with quotes!
sentence= 'I'm using single quotes, but this will create an error'
print(sentence)
# Out:
#   File "<ipython-input-15-5e7b6d7da870>", line 2
#     sentence= 'I'm using single quotes, but this will create an error'
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# * The reason for the error above is because the single quote in <code>I'm</code> stopped the string. You can use combinations of double and single quotes to get the complete statement.

# %%
sentence= "I'm using single quotes, but this will create an error"
print(sentence)
# Out:
# I'm using single quotes, but this will create an error

# %%
hashtag = "# @ $ % ^ & * ( )"
print(hashtag)
# Out:
# # @ $ % ^ & * ( )

# %%
type(hashtag)
# Out:
# str

# %% [markdown]
# ### How to print strings

# %% [markdown]
# * Using Jupyter notebook with just a string in a cell will automatically output strings, but the correct way to display strings in your output is by using a print function.

# %%
4+6
x =  10

# %%
# We can simply declare a string
'Deep Learning'
# Out:
# 'Deep Learning'

# %%
print('Deep Learning')
# Out:
# Deep Learning

# %%
# Note that we can't output multiple strings this way
'Linear Algebra'
'String'
'Calculus'
# Out:
# 'Calculus'

# %%
print('Linear Algebra')
print('String')
print('Calculus')
# Out:
# Linear Algebra
# String
# Calculus

# %% [markdown]
# ### We can use the <code>print()</code> statement to print a string.

# %%
print("RochitJain")
# Out:
# RochitJain

# %%
print("Rochit\nJain") # \n new line escape character
# Out:
# Rochit
# Jain

# %%
# print('Linear Algebra')
# print('Calculus')
print('Use \n\n\n to print a new\n line')
print('\n')
print('See what \n I mean?')
# Out:
# Use
#
#
#  to print a new
#  line
#
#
# See what
#  I mean?

# %%
print("Almabetter! is best")
# Out:
# Almabetter! is best

# %%
print("Almabetter!\nis best")
# Out:
# Almabetter!
# is best

# %%
print("Almabetter!\tis best")
# Out:
# Almabetter!	is best

# %% [markdown]
# ## Playing with strings

# %% [markdown]
# * We can also use a function called <code>len()</code> to check the length of a string!

# %%
algo = 'regres sion '
len(algo)
# Out:
# 12

# %%
var1 = "Length"

# %%
var2 = "Python's built-in len() function counts all of the characters in the string, including spaces and punctuation."

# %%
len(var2)
# Out:
# 110

# %%
my_name = "Rochit Jain"
len(my_name)
# Out:
# 11

# %%
print('amar \n singh \n chouhan')
# Out:
# amar
#  singh
#  chouhan

# %% [markdown]
# ### <b> Python's built-in len() function counts all of the characters in the string, including spaces and punctuation. </b>

# %% [markdown]
# ### <u> String Indexing </u>
#
# * We know strings are a sequence, which means Python can use indexes to call parts of the sequence.
#
#
# * A string index refers to the location of an element present in a string.
#
#
# * The indexing begins from 0 in Python.
#
#
# * The first element is assigned an index 0, the second element is assigned an index of 1 and so on and so forth.
#
#
# * In Python, we use brackets <code>[]</code> after variable name (object) to call its index.

# %%
# Assign string as a string
string  = 'Principal Component Analysis!'

# %%
# Print the object
print(string)
# Out:
# Principal Component Analysis!

# %% [markdown]
# * Let's start indexing!

# %%
string[0]
# Out:
# 'P'

# %%
string[4]
# Out:
# 'c'

# %%
# Show first element (in this case a letter)
print(string[0])
# Out:
# P

# %%
print(string[15])
# Out:
# n

# %%
len(string)
# Out:
# 29

# %%
print(string)
# Out:
# Principal Component Analysis!

# %%
# Grab the element at the index -1, which is the LAST element
print(string[-1])
# Out:
# !

# %%
# Last element
n = len(string) # length of string - 1
string[n-1]
# Out:
# '!'

# %%
# Hastag is for comments
# Second Last String
print(string[-2])
# Out:
# s

# %%
string2 = "HELLO"

string2[4]
# Out:
# 'O'

# %% [markdown]
# ### String Slicing

# %% [markdown]
# * We can use a <code>:</code> to perform *slicing* which grabs everything up to a designated point.
#
#
# * The starting index is specified on the left of the <code>:</code> and the ending index is specified on the right of the <code>:</code>.
#
#
# * Remember the element located at the right index is not included.

# %%
X = "Hello"

X[0:3]
# Out:
# 'Hel'

# %%
# Starting index
string[10]
# Out:
# 'C'

# %%
# Ending index
string[19]
# Out:
# ' '

# %%
print(string)
# Out:
# Principal Component Analysis!

# %%
# Slice only Component out of the string
string[10:19]
# Out:
# 'Component'

# %%
# Grab everything past the first term all the way to the length of s which is len(s)
print(string)
print(string[:13])
# Out:
# Principal Component Analysis!
# Principal Com

# %%
string[13]
# Out:
# 'p'

# %%
string[12]
# Out:
# 'm'

# %%
string[  :10] # Not specifying startinh index - 0
# Out:
# 'Principal '

# %%
string[10:]
# Out:
# 'Component Analysis!'

# %%
string[:]
# Out:
# 'Principal Component Analysis!'

# %%
# Grab everything starting from index 10 till end
print(string[10:])
# Out:
# Component Analysis!

# %% [markdown]
# * If you do not specify the ending index, then all elements are extracted which comes after the starting index including the element at that starting index. The operation knows only to stop when it has run through the entire string.

# %%
print(string[3:5])
# Out:
# nc

# %% [markdown]
# * If you do not specify the starting index, then all elements are extracted which comes befores the ending index excluding the element at the specified ending index. The operation knows only to stop when it has extracted all elements before the  element at the ending index.

# %%
print(string[:4])
# Out:
# Prin

# %% [markdown]
# * If you do not specify the starting and the ending index, it will extract all elements of the string.

# %%
#Everything
print(string[:])
print(string)
# Out:
# Principal Component Analysis!
# Principal Component Analysis!

# %% [markdown]
# * We can also use negative indexing to go backwards.

# %%
# Last letter (one index behind 0 so it loops back around)
string[-29]
# Out:
# 'P'

# %% [markdown]
# * We can also extract the last four elements. Remember we can use the index -4 to extract the FOURTH LAST element

# %%
string
# Out:
# 'Principal Component Analysis!'

# %%
string[-4:]
# Out:
# 'sis!'

# %%
string[-1:-4]
# Out:
# ''

# %%
string[-4:]
# Out:
# 'sis!'

# %% [markdown]
# * We can also use index and slice notation to grab elements of a sequence by a specified step size (the default is 1). For instance we can use two colons in a row and then a number specifying the frequency to grab elements. For example:

# %%
# Grab everything, but go in steps size of 1
print(string[::1])
# Out:
# Principal Component Analysis!

# %%
# Step size of 2
print(string[::2])
# Out:
# PicplCmoetAayi!

# %%
# Grab everything, but go in step sizes of 5
print(string[::5])
# Out:
# PiCnAs

# %%
string[::1]
# Out:
# 'Principal Component Analysis!'

# %%
# We can use this to print a string backwards
string[::-1]
# Out:
# '!sisylanA tnenopmoC lapicnirP'

# %%
# We can use this to print a string backwards with steps
string[2:4:-1]
# Out:
# ''

# %%
string[4:2:-1]
# Out:
# 'cn'

# %%
s = 'foobar'
s[0::-3]
# Out:
# 'f'

# %% [markdown]
# ## String Properties
#
# * It's important to note that strings have an important property known as *immutability*.
#
#
# * This means that once a string is created, the elements within it can not be changed or replaced via item assignment. We will see how we can do such operation using string methods

# %%
s = "Hello"
s[0] = 'C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-787e5a0b890c> in <module>
#       1 s = "Hello"
# ----> 2 s[0] = 'C'
#
# TypeError: 'str' object does not support item assignment

# %%
# Can we change our string 'Hello' to 'Cello'? Lets try replacing the first letter H with C
string='Hello'
string[0] = 'C'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-f55372fc219f> in <module>
#       1 # Can we change our string 'Hello' to 'Cello'? Lets try replacing the first letter H with C
#       2 string='Hello'
# ----> 3 string[0] = 'C'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# * Notice how the error tells us directly what we can't do, that is we can't change the item assignment!
#
#
# * Something we *can* do is concatenate strings!

# %%
34 + 6
# Out:
# 40

# %%
"alma"+"better" + 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-5adf1ba46d84> in <module>
# ----> 1 "alma"+"better" + 20
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Concatenate strings!
string1='abc'
string2='def'
print(string1 + ' ' + string2 )
# Out:
# abc def

# %%
print(string1 + 4 + string2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-544903aa2d55> in <module>
# ----> 1 print(string1 + 4 + string2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Convert an integer to str
str(232837823)
# Out:
# '232837823'

# %% [markdown]
# * To convert an integer into a string, you can use the <code>str()</code> function or you can simply write the number in quotes

# %%
# Concatenate strings!

string1='abc'
string2='def'
num = 4
print(string1 + str(4) + string2)
# Out:
# abc4def

# %%
str(num)
# Out:
# '4'

# %%
# Concatenate strings!
string1='abc'
string2='def'
string1 + '4'+ string2
# Out:
# 'abc4def'

# %%
print(string)
# Out:
# Hello

# %%
# We can reassign string completely though!
string = string + ' concatenate me!'
print(string)
# Out:
# Hello concatenate me!

# %%
# Write this 100 Times!!!!!
print(" i' m sorry Teacher i will not do it again!\n"*100)
# Out:
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!
#  i' m sorry Teacher i will not do it again!

# %%
letters = 'wubba'
letters*3
# Out:
# 'wubbawubbawubba'

# %% [markdown]
# ## String functions and methods

# %%
algorithm = 'Neural Networks'

print(algorithm)
# Out:
# Neural Networks

# %% [markdown]
# ### <code>len()</code>
#
# * <code>len()</code> function returns the length of the string

# %%
# Print the length of the string
len(algorithm)
# Out:
# 15

# %% [markdown]
# ###  <code>lower()</code>
#
# * <code>lower()</code> method converts the string to lowercase

# %%
type(algorithm)
# Out:
# str

# %%
# Conver the string to lowercase
algorithm.lower()
# Out:
# 'neural networks'

# %%
print(algorithm)
# Out:
# Neural Networks

# %% [markdown]
# * <u> What about <code>lower(algorithm)</code>? Is it not similar to the <code>len()</code>function?</u>
#
#
# * <u> An important point to note here is <code>len()</code> is a function and <code>lower()</code> is a method for a string object. It will be pretty clear about the exact differences between a function and a method as we move ahead. </u>

# %%
# Lets try that out
lower(algorithm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-4d609230893c> in <module>()
#       1 # Lets try that out
# ----> 2 lower(algorithm)
#
# NameError: name 'lower' is not defined

# %% [markdown]
# ###  <code>upper()</code>
#
# * <code>upper()</code> method converts the string to uppercase

# %%
print(algorithm)
# Out:
# Neural Networks

# %%
# Convert the string to uppercase
algorithm.upper()
# Out:
# 'NEURAL NETWORKS'

# %%
print(algorithm)
# Out:
# Neural Networks

# %%
algorithm.title()
# Out:
# 'Neural Networks'

# %% [markdown]
# ### <code>count()</code>
#
# *  <code>count()</code> method returns the count of a string in the given string. Unlike <code>lower()</code> and <code>upper()</code> method, the <code>count()</code> method takes a string as an argument

# %%
print(algorithm)
# Out:
# Neural Networks

# %%
algorithm.count('N')
# Out:
# 2

# %%
algorithm.count('Ne')
# Out:
# 2

# %%
algorithm.count('eu')
# Out:
# 1

# %%
algorithm.count(' ')
# Out:
# 1

# %%
algorithm.count('Neural')
# Out:
# 1

# %%
algorithm.count('Neurla')
# Out:
# 0

# %%
name = 'kushang bholu bhoot pisaj taksaknag gomi'

# %%
name.count("bhoot")
# Out:
# 1

# %%
name.find('bhoot')
# Out:
# 14

# %%
name[name]

# %% [markdown]
# ### <code>find()</code>
#
# * <code>find()</code> method returns the index of the first occurrence of a string present in a given string. Similar to the <code>count()</code> method, the <code>find()</code> method takes a string as an argument

# %%
string.find('c')
# Out:
# 6

# %%
string.rfind('c')
# Out:
# 9

# %%
string.find('almabetter')
# Out:
# -1

# %%
string.find('c')
# Out:
# 6

# %%
string.find('H')
# Out:
# 0

# %%
print(algorithm)
# Out:
# Neural Networks

# %%
algorithm.find('e')
# Out:
# 1

# %%
algorithm.find('Neural')
# Out:
# 0

# %%
algorithm.find('Box')
# Out:
# -1

# %% [markdown]
# * <u>An important point to note here is that if the string which you are looking for, is not contained in the original string, then the find method will return a value of -1 </u>

# %% [markdown]
# ### <code>replace()</code>
#
# *  <code>replace()</code> method takes two arguments - (i) the string to replace and (ii) the string to replace with, and returns a modified string after the operation

# %%
print(algorithm)
# Out:
# Neural Networks

# %%
algorithm.replace(' ','-')
# Out:
# 'Neural-Networks'

# %%
algorithm.replace('N','L')
# Out:
# 'Leural Letworks'

# %%
algorithm.replace(' ', 'alma')
# Out:
# 'NeuralalmaNetworks'

# %%
print(algorithm)
# Out:
# Neural Networks

# %% [markdown]
# * <u>Another important point worth noting here is applying any method on a string does not actually change the original string. For example, when you print out the algorithm string, it still contains the original value 'Neural Networks'</u>
#
#
# * <u> We need to store the modified string in another variable

# %%
# Storing the modified string
algorithm_revised  = algorithm.replace('Neural','Artificial Neural')
print(algorithm_revised)
print(algorithm)
# Out:
# Artificial Neural Networks
# Neural Networks

# %% [markdown]
# ### Printing strings a bit differently

# %%
# String Formatting
first_name = 'Rahul'
last_name = 'Modi'
var_int = 2020

fullname = f"{first_name}  x   {last_name} {var_int} {var_int}"
fullname
# Out:
# 'Rahul  x   Modi 2020 2020'

# %%
first_name = 'Rahul'
last_name = 'Modi'

full_name = f'Left plus right makes {first_name}  {last_name}'  # Use {} to print the variable you want to
print(full_name)
# Out:
# Left plus right makes Rahul  Modi

# %%
print(first_name + ' '+last_name)
# Out:
# Rahul Modi

# %%
first_name = 'Vikash'
middle_name = ''
last_name = 'Srivastava'

full_name = f'I am none other than {first_name} {middle_name}{last_name}. I am a Data Scientist'
print(full_name)
# Out:
# I am none other than Vikash Srivastava. I am a Data Scientist

# %%
print(f'I am none other than {first_name} {middle_name}{last_name}. I am a Data Scientist')
# Out:
# I am none other than Vikash Srivastava. I am a Data Scientist

# %% [markdown]
# ### Check if a string contains a particular word or character

# %%
my_string = 'Albert Einstein'

# %%
'Albert' in my_string
# Out:
# True

# %%
'Alberta' in my_string
# Out:
# False

# %%
name = input("Enter your First name")
s_name = input("Enter Your Second Name")
age = int(input("Mention your age as well"))
#f is called "formate string"
o = f""" 
my first name is {name}
my second name is {s_name}
and my age is {age}
"""

print(o)
# Out:
# Enter your First namebhoot
# Enter Your Second Namepisaj
# Mention your age as well190091190091
#
# my first name is bhoot
# my second name is pisaj
# and my age is 190091190091

# %%
'Neural' in algorithm
# Out:
# True

# %%
input().split()
# Out:
# Kushang Shah
# ['Kushang', 'Shah']

# %%
a = 10
b = 20
print(a, b)

c = a
a = b
b = c

print(a, b)
# Out:
# 10 20
# 20 10
